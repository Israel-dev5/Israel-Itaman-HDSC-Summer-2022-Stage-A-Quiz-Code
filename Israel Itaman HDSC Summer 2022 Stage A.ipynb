# %%
import numpy as np
import pandas as pd

df = pd.read_csv('/Users/ISRAEL/Downloads/FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding='latin-1')
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
# Question 11

Year = df.groupby('Item')['Y2014'].sum()
Year2 = df.groupby('Item')['Y2017'].sum()

print(Year['Animal fats'])
print(Year2['Animal fats'])
# Out:
# 209460.54
# 269617.53

# %%
# Question 12

print(df['Y2015'].mean())
print(df['Y2015'].std())


#rounded to 3 decimal places
# 135.236
# 1603.404
# Out:
# 135.23596649549236
# 1603.4039839423301

# %%
# Question 13

print(df['Y2016'].isnull().sum())

# Total entry expected = 60948

print((1535/60948) * 100)

# rounded to 2 decimal places
# 2.52
# Out:
# 1535
# 2.518540395090897

# %%
# Question 14

df.corr()

# Year with highest correlation with 'Element code' is 2014
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %%
# Question 15

ImportQuantity = df.groupby('Element')[['Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018']].sum()

print(ImportQuantity.loc['Import Quantity'])

# Year with highest sum of import quantity is 2017
# Out:
# Y2014    274144.48
# Y2015    267018.46
# Y2016    286582.78
# Y2017    294559.09
# Y2018    287997.09
# Name: Import Quantity, dtype: float64

# %%
# Question 16

df.groupby('Element')['Y2014'].sum()

# Total number of production in 2014 = 1931287.75
# Out:
# Element
# Domestic supply quantity                  1996716.35
# Export Quantity                            150020.64
# Fat supply quantity (g/capita/day)          10225.56
# Feed                                       216927.89
# Food                                      1212332.49
# Food supply (kcal/capita/day)              454257.00
# Food supply quantity (kg/capita/yr)         49650.63
# Import Quantity                            274144.48
# Losses                                     153223.00
# Other uses (non-food)                       78718.13
# Processing                                 282923.00
# Production                                1931287.75
# Protein supply quantity (g/capita/day)      11836.46
# Residuals                                   30149.00
# Seed                                        21922.92
# Stock Variation                             58749.83
# Total Population - Both sexes             1031585.00
# Tourist consumption                           416.00
# ...

# %%
# Question 17

print(df.groupby('Element')['Y2018'].sum().max())

print(df.groupby('Element')['Y2018'].sum())

# Domestic supply quantity
# Out:
# 2161192.1
# Element
# Domestic supply quantity                  2161192.10
# Export Quantity                            181594.80
# Fat supply quantity (g/capita/day)          10258.69
# Feed                                       233489.68
# Food                                      1303841.28
# Food supply (kcal/capita/day)              455261.00
# Food supply quantity (kg/capita/yr)         49056.85
# Import Quantity                            287997.09
# Losses                                     163902.00
# Other uses (non-food)                       91300.97
# Processing                                 308429.00
# Production                                2075072.89
# Protein supply quantity (g/capita/day)      11833.56
# Residuals                                   34864.00
# Seed                                        25263.14
# Stock Variation                             20577.91
# Total Population - Both sexes             1140605.00
# ...

# %%
# Question 18

df.groupby('Element')['Y2018'].sum()

# Third lowest sum is Fat Supply quantity
# Out:
# Element
# Domestic supply quantity                  2161192.10
# Export Quantity                            181594.80
# Fat supply quantity (g/capita/day)          10258.69
# Feed                                       233489.68
# Food                                      1303841.28
# Food supply (kcal/capita/day)              455261.00
# Food supply quantity (kg/capita/yr)         49056.85
# Import Quantity                            287997.09
# Losses                                     163902.00
# Other uses (non-food)                       91300.97
# Processing                                 308429.00
# Production                                2075072.89
# Protein supply quantity (g/capita/day)      11833.56
# Residuals                                   34864.00
# Seed                                        25263.14
# Stock Variation                             20577.91
# Total Population - Both sexes             1140605.00
# Tourist consumption                            90.00
# ...

# %%
# Question 19

df2 = df[df['Area']=='Algeria']

df2.groupby('Element')[["Element", "Y2018"]].sum()

# Total import quantity in Algeria in 2018 is 36238.29
# Out:
#                                            Y2018
# Element
# Domestic supply quantity                90023.42
# Export Quantity                           811.54
# Fat supply quantity (g/capita/day)        309.09
# Feed                                    10668.00
# Food                                    63736.33
# Food supply (kcal/capita/day)           13288.00
# Food supply quantity (kg/capita/yr)      1509.28
# Import Quantity                         36238.29
# Losses                                   7708.00
# Other uses (non-food)                    3970.08
# Processing                               2479.00
# Production                              60766.67
# Protein supply quantity (g/capita/day)    367.28
# Residuals                                 630.00
# Seed                                      825.00
# Stock Variation                          6172.00
# Total Population - Both sexes           42228.00

# %%
df['Area'].describe()

# Total number of unique countries is 49
# Out:
# count     60943
# unique       49
# top       Kenya
# freq       1560
# Name: Area, dtype: object
